# %%
url = 'https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD'

# %%
# # import requests
# from urllib2.request import urlretrive
# res = request.r
# if res == 200:
#     with open('fremont.csv') as f:
#         f.write(res.content)

# %%
# !ls
# Out:
# DataAnalysis.ipynb
# Fremont_Bridge_Hourly_Bicycle_Counts_by_Month_October_2012_to_present.csv

# %%
import pandas as pd
data = pd.read_csv('Fremont_Bridge_Hourly_Bicycle_Counts_by_Month_October_2012_to_present.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge West Sidewalk  \
# Date
# 2012-10-03 00:00:00                             4
# 2012-10-03 01:00:00                             4
# 2012-10-03 02:00:00                             1
# 2012-10-03 03:00:00                             2
# 2012-10-03 04:00:00                             6
#
#                      Fremont Bridge East Sidewalk
# Date
# 2012-10-03 00:00:00                             9
# 2012-10-03 01:00:00                             6
# 2012-10-03 02:00:00                             1
# 2012-10-03 03:00:00                             3
# 2012-10-03 04:00:00                             1

# %%
data.describe()
# Out:
#        Fremont Bridge West Sidewalk  Fremont Bridge East Sidewalk
# count                  39377.000000                  39377.000000
# mean                      53.549483                     53.283567
# std                       70.077714                     77.265108
# min                        0.000000                      0.000000
# 25%                        7.000000                      7.000000
# 50%                       29.000000                     27.000000
# 75%                       71.000000                     65.000000
# max                      698.000000                    717.000000

# %%
data.count()
# Out:
# Fremont Bridge West Sidewalk    39377
# Fremont Bridge East Sidewalk    39377
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 39384 entries, 2012-10-03 00:00:00 to 2017-03-31 23:00:00
# Data columns (total 2 columns):
# Fremont Bridge West Sidewalk    39377 non-null float64
# Fremont Bridge East Sidewalk    39377 non-null float64
# dtypes: float64(2)
# memory usage: 923.1 KB

# %%
# ?plot()
# Out:
# Object `plot` not found.

# %%
data.plot(figsize=(16,8),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fdea99a67d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fdea9955910>], dtype=object)

# %%
# %matplotlib inline

# %%
# data.plot()
# data.resample('W').sum().plot()
data.resample('W').plot()

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# [u'seaborn-darkgrid', u'seaborn-notebook', u'seaborn-muted', u'seaborn-ticks', u'grayscale', u'bmh', u'seaborn-talk', u'dark_background', u'ggplot', u'fivethirtyeight', u'seaborn-colorblind', u'seaborn-deep', u'seaborn-whitegrid', u'seaborn-bright', u'seaborn-poster', u'classic', u'seaborn-paper', u'seaborn-white', u'seaborn-pastel', u'seaborn-dark', u'seaborn-dark-palette']

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
data.columns = ['West', 'East']
data.resample('W').plot()#.sum().plot()

# %%
# !sudo pip install seaborn
# Out:
# [sudo] password for perlzuser:

# %%
# pd.style.available


data.resample('W').plot()

# data.resample('D').rolling()
import numpy as np
df = pd.DataFrame({'B': [0, 1, 2, np.nan, 4]})

# %% [markdown]
# ###

# %%
# df.rolling()
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 2.7.12.final.0
# python-bits: 64
# OS: Linux
# OS-release: 4.4.0-75-generic
# machine: x86_64
# processor: x86_64
# byteorder: little
# LC_ALL: None
# LANG: en_IN
#
# pandas: 0.17.1
# nose: 1.3.7
# pip: 9.0.1
# setuptools: 20.7.0
# Cython: None
# numpy: 1.11.0
# scipy: 0.17.0
# statsmodels: 0.6.1
# IPython: 5.2.2
# sphinx: None
# patsy: 0.4.1
# dateutil: 2.6.0
# pytz: 2014.10
# blosc: None
# bottleneck: None
# tables: 3.2.2
# numexpr: 2.4.3
# matplotlib: 1.5.1
# openpyxl: 2.3.0
# xlrd: 1.0.0
# xlwt: 0.7.5
# xlsxwriter: None
# lxml: 3.5.0
# bs4: 4.4.1
# html5lib: 0.9999999
# httplib2: None
# apiclient: None
# sqlalchemy: None
# pymysql: 0.7.2.None
# psycopg2: None
# Jinja2: None

# %%
# data.round
rolled_data=data.resample('D')
d = pd.rolling_sum(rolled_data, window=365)

# %%
d.plot()

# %%
rolled_data=data.resample('D')
d = pd.rolling_sum(rolled_data, window=180)
d.plot()

# %%
rolled_data=data.resample('D')
d = pd.rolling_sum(rolled_data, window=365).plot()
d.set_ylim(0,None);

# %%
data.groupby(data.index.time).mean()
# Out:
#                 West        East       Total
# 00:00:00    5.460085    6.861670   12.321755
# 01:00:00    3.037172    3.527727    6.564899
# 02:00:00    2.249695    2.189866    4.439560
# 03:00:00    1.636807    1.382084    3.018891
# 04:00:00    3.441194    2.580743    6.021938
# 05:00:00   16.243754    8.507617   24.751371
# 06:00:00   58.133455   29.642291   87.775746
# 07:00:00  153.471054   62.817794  216.288848
# 08:00:00  204.118830   98.149909  302.268739
# 09:00:00  111.527439   69.110366  180.637805
# 10:00:00   54.920732   39.964634   94.885366
# 11:00:00   46.049390   36.179878   82.229268
# 12:00:00   47.695122   40.250610   87.945732
# 13:00:00   49.696527   44.252285   93.948812
# 14:00:00   51.977453   50.295551  102.273004
# 15:00:00   60.854357   67.593541  128.447898
# 16:00:00   82.851920  125.237660  208.089580
# 17:00:00  113.916514  250.242535  364.159049
# 18:00:00   92.441804  166.413163  258.854966
# 19:00:00   50.288848   75.944546  126.233394
# ...

# %%
data['Total'] = data['West']+data['East']
data.groupby(data.index.time).mean().plot()

# %%
pivoted = data.pivot_table('Total', index=data.index.time,columns=data.index.date)
pivoted.iloc[:5,:5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00          13          18          11          15          11
# 01:00:00          10           3           8          15          17
# 02:00:00           2           9           7           9           3
# 03:00:00           5           3           4           3           6
# 04:00:00           7           8           9           5           3

# %%
pivoted.plot(legend=False)

# %%
pivoted.plot(legend=False, figsize=(10,8), alpha=0.01)
